# %%
import numpy as np
from scipy import linalg
M = np.array([ [0.8, 0.3], [0.2, 0.7]])
P, L, U = linalg.lu(M) # lệnh lina.lu sẽ tách ma trận M thành 3 ma trận P, L và U
print("Ma trận P:\n", P)
print("Ma trận L:\n", L)
print("Ma trận U:\n", U)
# Thử lại với phép nhân LU có bằng ma trận M ban đầu hay không:
print("Tích ma trận L và U:\n", L.dot(U))
# Out:
# Ma trận P:
#  [[1. 0.]
#  [0. 1.]]
# Ma trận L:
#  [[1.   0.  ]
#  [0.25 1.  ]]
# Ma trận U:
#  [[0.8   0.3  ]
#  [0.    0.625]]
# Tích ma trận L và U:
#  [[0.8 0.3]
#  [0.2 0.7]]
